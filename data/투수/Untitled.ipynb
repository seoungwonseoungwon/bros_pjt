# %%
import pandas as pd

# %%
bb = pd.read_csv("23Samsung_pitching__records.csv")

# %%
bb
# Out:
#     id  name team   war  games_played  complete_games  shutouts  \
# 0    1   뷰캐넌  23삼  2.51            17               1         0
# 1    2   원태인  23삼  1.83            15               0         0
# 2    3   백정현  23삼  1.30            13               0         0
# 3    4  수아레즈  23삼  0.89            16               0         0
# 4    5   김대우  23삼  0.50            25               0         0
# 5    6   이재익  23삼  0.42            18               0         0
# 6    7   이승현  23삼  0.36            33               0         0
# 7    8   문용익  23삼  0.35            12               0         0
# 8    9   이호성  23삼  0.19             3               0         0
# 9   10   이재희  23삼  0.15             2               0         0
# 10  11   황동재  23삼  0.08             3               0         0
# 11  12   최지광  23삼  0.03             6               0         0
# 12  13   박세웅  23삼  0.03             1               0         0
# 13  14   오승환  23삼  0.02            26               0         0
# ...

# %%
import pandas as pd

# Assuming '23dosan_pitching_records' is your DataFrame containing the pitching data
# Extract data of the 10 pitching players
players_data = [
    'Player1', 'Player2', 'Player3', 'Player4', 'Player5',
    'Player6', 'Player7', 'Player8', 'Player9', 'Player10'
]

# Use .loc method to get the data for these players
data_of_10_players = aa.loc[aa['이름'].isin(players_data)]

# Display the data
print(data_of_10_players)
# Out:
# Empty DataFrame
# Columns: [순, 이름, 팀, WAR, 출장, 완투, 완봉, 선발, 승, 패, 세, 홀드, 이닝, 실점, 자책, 타자, 피안타, 피2타, 피3타, 피홈런, 볼넷, 고4, 사구, 삼진, 보크, 폭투, ERA, FIP, wOBA, WHIP, ERA+, FIP+, WAR.1]
# Index: []
#
# [0 rows x 33 columns]

# %%
import pandas as pd

# Assuming your DataFrame is named 'data'
bb['team'] = bb['team'].replace({
    '23삼': '삼성',
    # Add other mappings for different team names here
})

# Now the '팀' column will have the new team names

# %%
bb
# Out:
#     id  name team   war  games_played  complete_games  shutouts  \
# 0    1   뷰캐넌   삼성  2.51            17               1         0
# 1    2   원태인   삼성  1.83            15               0         0
# 2    3   백정현   삼성  1.30            13               0         0
# 3    4  수아레즈   삼성  0.89            16               0         0
# 4    5   김대우   삼성  0.50            25               0         0
# 5    6   이재익   삼성  0.42            18               0         0
# 6    7   이승현   삼성  0.36            33               0         0
# 7    8   문용익   삼성  0.35            12               0         0
# 8    9   이호성   삼성  0.19             3               0         0
# 9   10   이재희   삼성  0.15             2               0         0
# 10  11   황동재   삼성  0.08             3               0         0
# 11  12   최지광   삼성  0.03             6               0         0
# 12  13   박세웅   삼성  0.03             1               0         0
# 13  14   오승환   삼성  0.02            26               0         0
# ...

# %%
import pandas as pd

# Assuming you have already read the CSV file into a DataFrame called 'df_pitcher'
# Replace 'df_pitcher' with the actual variable name of your DataFrame

# Define the new column names
new_columns = {
    '순': 'id',
    '이름': 'name',
    '팀': 'team',
    'WAR': 'war',
    '출장': 'games_played',
    '완투': 'complete_games',
    '완봉': 'shutouts',
    '선발': 'games_started',
    '승': 'wins',
    '패': 'losses',
    '세': 'saves',
    '홀드': 'holds',
    '이닝': 'innings_pitched',
    '실점': 'runs_allowed',
    '자책': 'earned_runs',
    '타자': 'batters_faced',
    '안타': 'hits_allowed',
    '2타': 'doubles_allowed',
    '3타': 'triples_allowed',
    '홈런': 'home_runs_allowed',
    '볼넷': 'walks_allowed',
    '고4': 'hit_by_pitch',
    '사구': 'intentional_walks',
    '삼진': 'strikeouts',
    '보크': 'balks',
    '폭투': 'wild_pitches',
    'ERA': 'era',
    'FIP': 'fip',
    'WHIP': 'whip',
    'ERA+': 'era_plus',
    'FIP+': 'fip_plus',
    'WAR.1': 'war_another_source',
    'WPA': 'wpa'
}

# Rename the columns in the DataFrame
bb.rename(columns=new_columns, inplace=True)

# Now the DataFrame 'df_pitcher' will have the updated column names

# %%
bb.to_csv("23Samsung_pitching__records.csv", index=False)

# %%
bb.columns
# Out:
# Index(['id', 'name', 'team', 'war', 'games_played', 'complete_games',
#        'shutouts', 'games_started', 'wins', 'losses', 'saves', 'holds',
#        'innings_pitched', 'runs_allowed', 'earned_runs', 'batters_faced',
#        'hits_allowed', 'doubles_allowed', 'triples_allowed',
#        'home_runs_allowed', 'walks_allowed', 'hit_by_pitch',
#        'intentional_walks', 'strikeouts', 'balks', 'wild_pitches', 'era',
#        'fip', 'wOBA', 'whip', 'era_plus', 'fip_plus', 'war_another_source'],
#       dtype='object')

# %%
bb["팀"]
# Out:
# 0     23K
# 1     23K
# 2     23K
# 3     23K
# 4     23K
# 5     23K
# 6     23K
# 7     23K
# 8     23K
# 9     23K
# 10    23K
# 11    23K
# 12    23K
# 13    23K
# 14    23K
# 15    23K
# 16    23K
# 17    23K
# 18    23K
# 19    23K
# 20    23K
# 21    23K
# 22    23K
# 23    23K
# Name: 팀, dtype: object

# %%
import pandas as pd

# Assuming your DataFrame is named 'data'
bb['팀'] = bb['팀'].replace({
    '23K': 'KIA',
    # Add other mappings for different team names here
})

# Now the '팀' column will have the new team names

# %%
bb.to_csv("23Kiwoom_pitching__records.csv", index=False)

# %%
bb
# Out:
#      순   이름    팀   WAR  출장  완투  완봉  선발  승  패  ...  삼진  보크  폭투   ERA   FIP  \
# 0    1  최지민  KIA  1.80  37   0   0   0  3  2  ...  33   0   4  1.70  3.77
# 1    2  임기영  KIA  1.49  33   0   0   0  1  1  ...  39   0   1  2.65  3.10
# 2    3  양현종  KIA  1.29  16   0   0  16  5  5  ...  82   0   2  3.79  3.28
# 3    4  이준영  KIA  1.25  38   0   0   0  1  0  ...  22   0   1  1.17  3.16
# 4    5  이의리  KIA  1.10  16   0   0  16  7  5  ...  94   0   3  3.82  3.61
# 5    6  윤영철  KIA  0.92  14   0   0  13  5  4  ...  39   1   4  4.08  3.90
# 6    7  정해영  KIA  0.67  24   0   0   0  3  1  ...  11   0   0  2.91  5.27
# 7    8  앤더슨  KIA  0.63  14   0   0  14  4  7  ...  64   0  10  3.76  3.80
# 8    9  전상현  KIA  0.51  34   0   0   0  1  1  ...  26   0   0  2.93  3.70
# 9   10  김유신  KIA  0.43  12   0   0   0  0  1  ...   3   0   0  2.70  5.92
# 10  11  산체스  KIA  0.35   1   0   0   1  1  0  ...  10   0   0  1.42  2.27
# 11  12  김기훈  KIA  0.28  22   0   0   0  2  0  ...  20   0   3  3.60  5.37
# ...
